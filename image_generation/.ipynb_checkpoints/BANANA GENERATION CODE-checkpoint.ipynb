# %%
# !python3 -m pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pillow
#   Downloading Pillow-9.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 2.4 MB/s
# Installing collected packages: pillow
# Successfully installed pillow-9.0.0

# %%
from PIL import Image, ImageOps
from IPython.display import display
import random
import json

# %%
### NECESSARY INFO

backgrounds = ["Red", "Orange", "Yellow", "Lime", "Green", "Sky", "Indigo", "Purple", "Pink", "Slate", "Stone"] #5 types
backgroundweights = [18, 16, 14, 14, 14, 7.5, 6.5, 3, 2.5, 2.25, 2.25]

heads =  ["Red", "Orange", "Yellow", "Lime", "Green", "Sky", "Indigo", "Purple", "Pink", "Slate", "Stone"] #7 types
headweights = [20.5, 19, 17.5, 16.75, 9.5, 6.5, 0.5, 1.75, 0.75, 0.25, 1.5, 1.65, 0.75, 1, 0.5, 0.35, 1.25]

faces =  ["Default", "Content", "Happy", "Grumpy"] #7 types
Faceweights = [8, 6, 6, 4, 3, 4, 3, 6, 9, 9, 9, 9, 1, 2, 3, 5, 2, 1, 5, 0.5, 0.5, 4]

bodies = ["Sweater", "Hoodies", "Suit and Tie"] #12 types
Bodyweights = [7.5, 5.5, 1.5, 6, 4.5, 4, 4, 3.5, 2, 5.5, 5, 4.25, 3.5, 0.5, 4, 4.5, 2, 1, 5.5, 2.5, 0.5, 3.5, 0.5, 0.25, 6.5, 4.5, 2, 2.5, 3]

headgears = ["Small Daisy", "Rice Hat", "Default"] # 28 types
headgearweights = [4.2, 3.8, 3, 3.6, 2.5, 3.7, 3.2, 2.1, 2.1, 4.3, 4.2, 3.8, 3.7, 4.2, 1.9, 3.2, 2.1, 3.1, 3.5, 1.4, 4.2, 3, 2.6, 4, 0.2, 4.2, 1.7, 1, 3.8, 0.6, 0.4, 0.3, 0.75, 0.75, 3.5, 2.5, 2.9]



backgroundfiles = {
    "Red": "bg1",
    "Orange": "bg2",
    "Yellow": "bg3",
    "Lime": "bg4",
    "Green": "bg5",
    "Sky": "bg6",
    "Indigo": "bg7",
    "Purple": "bg8",
    "Pink": "bg9",
    "Slate": "bg10",
    "Stone": "bg11"
}

headfiles = {
    "Red": "hd1",
    "Orange": "hd2",
    "Yellow": "hd3",
    "Lime": "hd4",
    "Green": "hd5",
    "Sky": "hd6",
    "Indigo": "hd7",
    "Purple": "hd8",
    "Pink": "hd9",
    "Slate": "hd10",
    "Stone": "hd11"
}

facefiles = {
    
    "Default" : "fc1",
    "Content" : "fc2",
    "Happy" : "fc3",
    "Grumpy" : "fc4"
     
}

bodyfiles = {
    "Sweater": "bd1",
    "Hoodies": "bd2",
    "Suit and Tie": "bd3"
}

headgearfiles = {
    "Small Daisy" : "he1",
    "Rice Hat" : "he2",
    "None" : "he3"
}

# %%
## TRAIT GENERATION

TOTAL_BANANAS = 2222

traits = []

def createCombo():
    
    trait = {}

    trait["Background"] = random.choice(backgrounds)
    trait["Head"] = random.choice(heads)
    trait["Face"] = random.choice(faces)
    trait["Body"] = random.choice(bodies)
    trait["Head Gear"] = random.choice(headgears)
    
    if trait in traits:
        return createCombo()
    else:
        return trait
    
for i in range(TOTAL_BANANAS):
    
    newtraitcombo = createCombo()
    
    traits.append(newtraitcombo)

# %%
## ARE ALL BANANAS UNIQUE? I DUNNO HOW THIS WORKS BUT IT WORKS
def allUnique(x):
    seen = list()
    return not any(i in seen or seen.append(i) for i in x)

print(allUnique(traits))
# Out:
# True

# %%
# ADD TOKEN IDS TO JSON

i = 0
for item in traits:
    item["tokenId"] = i
    i = i + 1

# %%
# PRINT THE SHIT

print(json.dumps(traits, indent=2))
# Out:
# [
#   {
#     "Background": "Sky",
#     "Banana Base": "Wonderland",
#     "Mouth": "Cherry Lips",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 0
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Pride",
#     "Mouth": "Pipe",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 1
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Dystopia",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 2
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Blue",
#     "Mouth": "Toothless",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 3
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Blue",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 4
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Bubblegum",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 5
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Dystopia",
#     "Eyes": "Hypno",
#     "Head Gear": "Small Daisy",
#     "tokenId": 6
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Peeled",
#     "Mouth": "Beatnik",
#     "Eyes": "Leonardo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 7
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Ruby",
#     "Mouth": "Happy",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Diamond",
#     "Mouth": "Whoops",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 9
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled",
#     "Mouth": "Dystopia",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 10
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Stripes",
#     "Mouth": "The Douche",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 11
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Yellow",
#     "Mouth": "Outbreak",
#     "Eyes": "Hypno",
#     "Head Gear": "Small Daisy",
#     "tokenId": 12
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Ruby",
#     "Mouth": "Smirk",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 13
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled",
#     "Mouth": "Meh",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 14
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Yellow",
#     "Mouth": "Trashy",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 15
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Diamond",
#     "Mouth": "Trashy",
#     "Eyes": "Yuyu",
#     "Head Gear": "Rice Hat",
#     "tokenId": 16
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 17
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Green",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 18
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Iridescent",
#     "Mouth": "Meh",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Small Daisy",
#     "tokenId": 19
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Pipe",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 20
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Camo",
#     "Mouth": "Whoops",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Small Daisy",
#     "tokenId": 21
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Stripes",
#     "Mouth": "Sulking",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 22
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Emerald",
#     "Mouth": "Happy",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 23
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Ruby",
#     "Mouth": "Pipe",
#     "Eyes": "Hangover",
#     "Head Gear": "Small Daisy",
#     "tokenId": 24
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Camo",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 25
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 26
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Iridescent",
#     "Mouth": "Toothpick",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 27
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Red",
#     "Mouth": "Lollipop",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 28
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Smirk",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 29
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Camo",
#     "Mouth": "Sulking",
#     "Eyes": "Cyclops",
#     "Head Gear": "Rice Hat",
#     "tokenId": 30
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 31
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Whistle",
#     "Eyes": "Bulge",
#     "Head Gear": "Rice Hat",
#     "tokenId": 32
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Red",
#     "Mouth": "Sulking",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Small Daisy",
#     "tokenId": 33
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Blue",
#     "Mouth": "Bubblegum",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 34
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Red",
#     "Mouth": "The Douche",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 35
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Bubblegum",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 36
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 37
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Pride",
#     "Mouth": "Bubblegum",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 38
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Camo",
#     "Mouth": "Sulking",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 39
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Meh",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 40
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Lollipop",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 41
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Iridescent",
#     "Mouth": "Toothpick",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 42
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled",
#     "Mouth": "Meh",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 43
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothless",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 44
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Yellow",
#     "Mouth": "Beatnik",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 45
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Gold",
#     "Mouth": "Outbreak",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 46
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Dystopia",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 47
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whistle",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 48
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Peeled",
#     "Mouth": "Cigar",
#     "Eyes": "Googly",
#     "Head Gear": "Small Daisy",
#     "tokenId": 49
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Green",
#     "Mouth": "Cigar",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 50
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Pride",
#     "Mouth": "Toothpick",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 51
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothpick",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 52
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Gold",
#     "Mouth": "Lollipop",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 53
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Doobie",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 54
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Iridescent",
#     "Mouth": "Bubblegum",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 55
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Toothless",
#     "Eyes": "Bored",
#     "Head Gear": "Small Daisy",
#     "tokenId": 56
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Red",
#     "Mouth": "Whistle",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 57
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Camo",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 58
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Yellow",
#     "Mouth": "Cigar",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 59
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Grrrr",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 60
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Ruby",
#     "Mouth": "Beatnik",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 61
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Ruby",
#     "Mouth": "Happy",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 62
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Peeled",
#     "Mouth": "Grrrr",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 63
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Peeled",
#     "Mouth": "Pipe",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 64
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Ruby",
#     "Mouth": "Trashy",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 65
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Happy",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 66
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Camo",
#     "Mouth": "Happy",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 67
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Gold",
#     "Mouth": "Outbreak",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 68
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Stripes",
#     "Mouth": "Pipe",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 69
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Green",
#     "Mouth": "Doobie",
#     "Eyes": "Pixel",
#     "Head Gear": "Small Daisy",
#     "tokenId": 70
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Stripes",
#     "Mouth": "Cigar",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 71
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Pride",
#     "Mouth": "Grrrr",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 72
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Green",
#     "Mouth": "Toothpick",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 73
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Red",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 74
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Camo",
#     "Mouth": "Happy",
#     "Eyes": "Yuyu",
#     "Head Gear": "Rice Hat",
#     "tokenId": 75
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Ruby",
#     "Mouth": "Doobie",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 76
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Happy",
#     "Eyes": "Conductor",
#     "Head Gear": "Small Daisy",
#     "tokenId": 77
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whistle",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 78
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Beatnik",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 79
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Blue",
#     "Mouth": "Dystopia",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 80
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Yellow",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 81
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Gold",
#     "Mouth": "Grrrr",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 82
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Emerald",
#     "Mouth": "The Douche",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Small Daisy",
#     "tokenId": 83
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Happy",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 84
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Emerald",
#     "Mouth": "Whoops",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 85
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothpick",
#     "Eyes": "Hangover",
#     "Head Gear": "Small Daisy",
#     "tokenId": 86
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Yellow",
#     "Mouth": "Smirk",
#     "Eyes": "Hangover",
#     "Head Gear": "Small Daisy",
#     "tokenId": 87
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Peeled",
#     "Mouth": "Sulking",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 88
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Green",
#     "Mouth": "Toothpick",
#     "Eyes": "Conductor",
#     "Head Gear": "Small Daisy",
#     "tokenId": 89
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Diamond",
#     "Mouth": "Bubblegum",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 90
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled",
#     "Mouth": "Grrrr",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 91
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Blue",
#     "Mouth": "Pipe",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 92
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Wonderland",
#     "Mouth": "Pipe",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 93
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Pipe",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 94
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Iridescent",
#     "Mouth": "Meh",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 95
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Pride",
#     "Mouth": "Beatnik",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 96
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Stripes",
#     "Mouth": "Bubblegum",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 97
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whoops",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 98
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Wonderland",
#     "Mouth": "Smirk",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 99
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Gold",
#     "Mouth": "The Douche",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 100
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Psychedelic",
#     "Mouth": "The Douche",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 101
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Gold",
#     "Mouth": "Toothpick",
#     "Eyes": "Trippy",
#     "Head Gear": "Small Daisy",
#     "tokenId": 102
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Pipe",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 103
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Green",
#     "Mouth": "Grrrr",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 104
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Camo",
#     "Mouth": "Smirk",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 105
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Peeled",
#     "Mouth": "Whistle",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 106
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Dystopia",
#     "Eyes": "Bored",
#     "Head Gear": "Rice Hat",
#     "tokenId": 107
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Yellow",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 108
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Blue",
#     "Mouth": "Sulking",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 109
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Green",
#     "Mouth": "Grrrr",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 110
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Yellow",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 111
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Red",
#     "Mouth": "Sulking",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 112
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Wonderland",
#     "Mouth": "Outbreak",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 113
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Red",
#     "Mouth": "Dystopia",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 114
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Wonderland",
#     "Mouth": "Cigar",
#     "Eyes": "Perplexed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 115
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Yellow",
#     "Mouth": "Doobie",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 116
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled",
#     "Mouth": "Tongue Ring",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 117
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Diamond",
#     "Mouth": "Sulking",
#     "Eyes": "Googly",
#     "Head Gear": "Small Daisy",
#     "tokenId": 118
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothless",
#     "Eyes": "Perplexed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 119
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Whoops",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 120
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Blue",
#     "Mouth": "Dystopia",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 121
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Ruby",
#     "Mouth": "Lollipop",
#     "Eyes": "Pixel",
#     "Head Gear": "Small Daisy",
#     "tokenId": 122
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 123
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Green",
#     "Mouth": "Whistle",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 124
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Yellow",
#     "Mouth": "Whistle",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 125
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Stripes",
#     "Mouth": "Toothless",
#     "Eyes": "Googly",
#     "Head Gear": "Small Daisy",
#     "tokenId": 126
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Peeled",
#     "Mouth": "Lollipop",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 127
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Toothpick",
#     "Eyes": "Cyclops",
#     "Head Gear": "Rice Hat",
#     "tokenId": 128
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Camo",
#     "Mouth": "Cigar",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 129
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Yellow",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 130
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Wonderland",
#     "Mouth": "Trashy",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 131
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Ruby",
#     "Mouth": "Meh",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 132
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Iridescent",
#     "Mouth": "Smirk",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 133
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Dystopia",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 134
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Ruby",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 135
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Beatnik",
#     "Eyes": "Carnival",
#     "Head Gear": "Small Daisy",
#     "tokenId": 136
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Red",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 137
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Camo",
#     "Mouth": "The Douche",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 138
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Diamond",
#     "Mouth": "Smirk",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 139
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "The Douche",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 140
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Green",
#     "Mouth": "Grrrr",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 141
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Emerald",
#     "Mouth": "Grrrr",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 142
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Camo",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Conductor",
#     "Head Gear": "Small Daisy",
#     "tokenId": 143
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Whistle",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 144
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled",
#     "Mouth": "Pipe",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 145
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Emerald",
#     "Mouth": "Toothpick",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 146
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Grrrr",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 147
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Yellow",
#     "Mouth": "Trashy",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 148
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Green",
#     "Mouth": "Bubblegum",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 149
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Toothpick",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 150
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Wonderland",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 151
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Pride",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 152
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Ruby",
#     "Mouth": "Grrrr",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 153
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Camo",
#     "Mouth": "Grrrr",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 154
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Iridescent",
#     "Mouth": "Sulking",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 155
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Stripes",
#     "Mouth": "Bubblegum",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 156
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Gold",
#     "Mouth": "Grrrr",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 157
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Iridescent",
#     "Mouth": "Grrrr",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 158
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 159
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Ruby",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 160
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Gold",
#     "Mouth": "Bubblegum",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 161
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Sulking",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 162
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Yellow",
#     "Mouth": "Whoops",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 163
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Gold",
#     "Mouth": "Outbreak",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 164
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Blue",
#     "Mouth": "Bubblegum",
#     "Eyes": "Hangover",
#     "Head Gear": "Small Daisy",
#     "tokenId": 165
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Blue",
#     "Mouth": "Meh",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 166
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Red",
#     "Mouth": "Pipe",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Small Daisy",
#     "tokenId": 167
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Pipe",
#     "Eyes": "Bored",
#     "Head Gear": "Rice Hat",
#     "tokenId": 168
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Lollipop",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 169
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Stripes",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 170
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Yellow",
#     "Mouth": "The Douche",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 171
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Blue",
#     "Mouth": "Happy",
#     "Eyes": "Leonardo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 172
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Stripes",
#     "Mouth": "Whoops",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 173
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Toothless",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 174
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Diamond",
#     "Mouth": "The Douche",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 175
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Wonderland",
#     "Mouth": "Smirk",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 176
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Toothpick",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 177
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Diamond",
#     "Mouth": "Smirk",
#     "Eyes": "Raphael",
#     "Head Gear": "Small Daisy",
#     "tokenId": 178
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Grrrr",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 179
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Iridescent",
#     "Mouth": "Smirk",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 180
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Iridescent",
#     "Mouth": "Cigar",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 181
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Meh",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 182
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Doobie",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 183
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Iridescent",
#     "Mouth": "Lollipop",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 184
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Pride",
#     "Mouth": "Toothless",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 185
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Stripes",
#     "Mouth": "Beatnik",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 186
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Peeled",
#     "Mouth": "Toothless",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 187
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Stripes",
#     "Mouth": "Doobie",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 188
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Red",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 189
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Camo",
#     "Mouth": "Toothless",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 190
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Wonderland",
#     "Mouth": "Sulking",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 191
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whoops",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 192
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Ruby",
#     "Mouth": "Meh",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 193
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Camo",
#     "Mouth": "Toothpick",
#     "Eyes": "Raphael",
#     "Head Gear": "Small Daisy",
#     "tokenId": 194
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Gold",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 195
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Red",
#     "Mouth": "Pipe",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 196
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Camo",
#     "Mouth": "Grrrr",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 197
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Ruby",
#     "Mouth": "Bubblegum",
#     "Eyes": "Bored",
#     "Head Gear": "Small Daisy",
#     "tokenId": 198
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Gold",
#     "Mouth": "Grrrr",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 199
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Pride",
#     "Mouth": "Outbreak",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 200
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Cigar",
#     "Eyes": "Perplexed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 201
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Green",
#     "Mouth": "Grrrr",
#     "Eyes": "Conductor",
#     "Head Gear": "Small Daisy",
#     "tokenId": 202
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Meh",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 203
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Camo",
#     "Mouth": "Pipe",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 204
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Pride",
#     "Mouth": "Pipe",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 205
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Stripes",
#     "Mouth": "Toothpick",
#     "Eyes": "Hangover",
#     "Head Gear": "Small Daisy",
#     "tokenId": 206
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Stripes",
#     "Mouth": "Beatnik",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 207
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Yellow",
#     "Mouth": "Pipe",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 208
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Bubblegum",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Small Daisy",
#     "tokenId": 209
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Camo",
#     "Mouth": "Cigar",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 210
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Emerald",
#     "Mouth": "Meh",
#     "Eyes": "Cyclops",
#     "Head Gear": "Rice Hat",
#     "tokenId": 211
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Diamond",
#     "Mouth": "Whoops",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 212
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Pride",
#     "Mouth": "Outbreak",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 213
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Red",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Hangover",
#     "Head Gear": "Rice Hat",
#     "tokenId": 214
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Doobie",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 215
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Camo",
#     "Mouth": "Toothpick",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 216
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Meh",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 217
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Gold",
#     "Mouth": "Sulking",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 218
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Gold",
#     "Mouth": "Toothless",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 219
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Pride",
#     "Mouth": "Lollipop",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 220
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Iridescent",
#     "Mouth": "Doobie",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 221
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Wonderland",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 222
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whoops",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 223
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Pride",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 224
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Red",
#     "Mouth": "Whoops",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 225
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Pride",
#     "Mouth": "Dystopia",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 226
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Red",
#     "Mouth": "Cigar",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 227
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Wonderland",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 228
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Stripes",
#     "Mouth": "Happy",
#     "Eyes": "Conductor",
#     "Head Gear": "Rice Hat",
#     "tokenId": 229
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled",
#     "Mouth": "Doobie",
#     "Eyes": "Yuyu",
#     "Head Gear": "Rice Hat",
#     "tokenId": 230
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Meh",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 231
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Blue",
#     "Mouth": "Smirk",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 232
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Ruby",
#     "Mouth": "Whistle",
#     "Eyes": "3D",
#     "Head Gear": "Small Daisy",
#     "tokenId": 233
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Yellow",
#     "Mouth": "Lollipop",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 234
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Beatnik",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 235
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Dystopia",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 236
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Camo",
#     "Mouth": "Sulking",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 237
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Pride",
#     "Mouth": "Smirk",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 238
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Green",
#     "Mouth": "Beatnik",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Small Daisy",
#     "tokenId": 239
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Stripes",
#     "Mouth": "Doobie",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 240
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Cigar",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 241
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Camo",
#     "Mouth": "Grrrr",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 242
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Gold",
#     "Mouth": "Doobie",
#     "Eyes": "Steampunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 243
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Yellow",
#     "Mouth": "Doobie",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 244
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Green",
#     "Mouth": "Whistle",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 245
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Stripes",
#     "Mouth": "Meh",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 246
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Smirk",
#     "Eyes": "Mysterious",
#     "Head Gear": "Small Daisy",
#     "tokenId": 247
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Red",
#     "Mouth": "Trashy",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 248
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Pipe",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 249
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Pride",
#     "Mouth": "Beatnik",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 250
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Camo",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 251
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Red",
#     "Mouth": "Dystopia",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 252
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Iridescent",
#     "Mouth": "Sulking",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 253
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Red",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 254
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Pride",
#     "Mouth": "Bubblegum",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 255
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Red",
#     "Mouth": "Whistle",
#     "Eyes": "Yuyu",
#     "Head Gear": "Rice Hat",
#     "tokenId": 256
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Toothless",
#     "Eyes": "Mysterious",
#     "Head Gear": "Small Daisy",
#     "tokenId": 257
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Diamond",
#     "Mouth": "Doobie",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 258
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Red",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 259
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Gold",
#     "Mouth": "Outbreak",
#     "Eyes": "Yuyu",
#     "Head Gear": "Rice Hat",
#     "tokenId": 260
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Pride",
#     "Mouth": "Pipe",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 261
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Stripes",
#     "Mouth": "Whistle",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 262
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Wonderland",
#     "Mouth": "Whistle",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 263
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Meh",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 264
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Green",
#     "Mouth": "Whistle",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 265
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothless",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 266
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Blue",
#     "Mouth": "Toothless",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 267
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Gold",
#     "Mouth": "Trashy",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 268
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Iridescent",
#     "Mouth": "Bubblegum",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 269
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Stripes",
#     "Mouth": "Cigar",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 270
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Candy Camo",
#     "Mouth": "The Douche",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 271
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Camo",
#     "Mouth": "Dystopia",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 272
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Pride",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 273
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Yellow",
#     "Mouth": "Toothless",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 274
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Beatnik",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 275
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Wonderland",
#     "Mouth": "Bubblegum",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 276
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Green",
#     "Mouth": "Grrrr",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 277
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Blue",
#     "Mouth": "Happy",
#     "Eyes": "Raphael",
#     "Head Gear": "Small Daisy",
#     "tokenId": 278
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Gold",
#     "Mouth": "Grrrr",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 279
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Blue",
#     "Mouth": "Meh",
#     "Eyes": "Carnival",
#     "Head Gear": "Small Daisy",
#     "tokenId": 280
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Bubblegum",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 281
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Red",
#     "Mouth": "Meh",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 282
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Diamond",
#     "Mouth": "Sulking",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 283
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Gold",
#     "Mouth": "Outbreak",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 284
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Peeled",
#     "Mouth": "The Douche",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 285
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Cigar",
#     "Eyes": "Steampunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 286
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Dystopia",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 287
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Yellow",
#     "Mouth": "Beatnik",
#     "Eyes": "Cyclops",
#     "Head Gear": "Rice Hat",
#     "tokenId": 288
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Diamond",
#     "Mouth": "Toothless",
#     "Eyes": "Stoner",
#     "Head Gear": "Small Daisy",
#     "tokenId": 289
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Yellow",
#     "Mouth": "Lollipop",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 290
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Emerald",
#     "Mouth": "Cigar",
#     "Eyes": "Bored",
#     "Head Gear": "Rice Hat",
#     "tokenId": 291
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Peeled",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 292
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Gold",
#     "Mouth": "Pipe",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 293
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Wonderland",
#     "Mouth": "Outbreak",
#     "Eyes": "Steampunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 294
#   },
#   {
#     "Background": "Indigo",
# ...
#     "Head Gear": "Small Daisy",
#     "tokenId": 8790
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Iridescent",
#     "Mouth": "The Douche",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8791
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Blue",
#     "Mouth": "Bubblegum",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8792
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Stripes",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8793
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Stripes",
#     "Mouth": "Meh",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8794
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Toothless",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8795
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Ruby",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8796
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Diamond",
#     "Mouth": "Meh",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8797
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Green",
#     "Mouth": "Outbreak",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8798
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Green",
#     "Mouth": "Smirk",
#     "Eyes": "Leonardo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8799
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Red",
#     "Mouth": "Cigar",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8800
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Blue",
#     "Mouth": "Bubblegum",
#     "Eyes": "Bulge",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8801
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Emerald",
#     "Mouth": "Sulking",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8802
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Green",
#     "Mouth": "Toothless",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8803
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Cigar",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8804
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Yellow",
#     "Mouth": "Pipe",
#     "Eyes": "Raphael",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8805
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8806
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Diamond",
#     "Mouth": "Whistle",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8807
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Diamond",
#     "Mouth": "Doobie",
#     "Eyes": "Carnival",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8808
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Dystopia",
#     "Eyes": "Hypno",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8809
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Green",
#     "Mouth": "Cigar",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8810
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Red",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8811
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Red",
#     "Mouth": "Happy",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8812
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Yellow",
#     "Mouth": "Doobie",
#     "Eyes": "Cyberpunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8813
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Blue",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8814
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Stripes",
#     "Mouth": "Smirk",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8815
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Wonderland",
#     "Mouth": "Pipe",
#     "Eyes": "Bulge",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8816
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Gold",
#     "Mouth": "Happy",
#     "Eyes": "Geeky",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8817
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Iridescent",
#     "Mouth": "Whoops",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8818
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Cigar",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8819
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Toothless",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8820
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Pride",
#     "Mouth": "Whoops",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8821
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Stripes",
#     "Mouth": "Outbreak",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8822
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Ruby",
#     "Mouth": "The Douche",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8823
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Green",
#     "Mouth": "Doobie",
#     "Eyes": "Perplexed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8824
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Wonderland",
#     "Mouth": "Toothpick",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8825
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Camo",
#     "Mouth": "Cigar",
#     "Eyes": "Carnival",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8826
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Wonderland",
#     "Mouth": "Outbreak",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8827
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Ruby",
#     "Mouth": "Happy",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8828
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Blue",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Raphael",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8829
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Red",
#     "Mouth": "Smirk",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8830
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Sulking",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8831
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Pride",
#     "Mouth": "Pipe",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8832
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Yellow",
#     "Mouth": "Trashy",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8833
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Red",
#     "Mouth": "Outbreak",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8834
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Camo",
#     "Mouth": "Lollipop",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8835
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Pride",
#     "Mouth": "Happy",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8836
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Yellow",
#     "Mouth": "Bubblegum",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8837
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Green",
#     "Mouth": "Dystopia",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8838
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Happy",
#     "Eyes": "3D",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8839
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Red",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Cyclops",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8840
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Yellow",
#     "Mouth": "Grrrr",
#     "Eyes": "Trippy",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8841
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Camo",
#     "Mouth": "The Douche",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8842
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Emerald",
#     "Mouth": "Meh",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8843
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Diamond",
#     "Mouth": "Beatnik",
#     "Eyes": "Steampunk",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8844
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Pride",
#     "Mouth": "Lollipop",
#     "Eyes": "Bored",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8845
#   },
#   {
#     "Background": "Purple",
#     "Banana Base": "Peeled",
#     "Mouth": "Pipe",
#     "Eyes": "Cross-eyed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8846
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Meh",
#     "Eyes": "Michelangelo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8847
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Stripes",
#     "Mouth": "Smirk",
#     "Eyes": "Pixel",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8848
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Ruby",
#     "Mouth": "Tongue Ring",
#     "Eyes": "Hypno",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8849
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Stripes",
#     "Mouth": "The Douche",
#     "Eyes": "Geeky",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8850
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Camo",
#     "Mouth": "Smirk",
#     "Eyes": "Wazowski",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8851
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Blue",
#     "Mouth": "Grrrr",
#     "Eyes": "The Green Gaze",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8852
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Emerald",
#     "Mouth": "Sulking",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8853
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Beatnik",
#     "Eyes": "Donatello",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8854
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Diamond",
#     "Mouth": "Happy",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8855
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Gold",
#     "Mouth": "Trashy",
#     "Eyes": "Bana-love",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8856
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Whistle",
#     "Eyes": "Perplexed",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8857
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Gold",
#     "Mouth": "Cigar",
#     "Eyes": "Carnival",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8858
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Toothpick",
#     "Eyes": "Hypno",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8859
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Red",
#     "Mouth": "Toothless",
#     "Eyes": "Bulge",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8860
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Sulking",
#     "Eyes": "Mysterious",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8861
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8862
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Pride",
#     "Mouth": "Grrrr",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8863
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Yellow",
#     "Mouth": "Whoops",
#     "Eyes": "Yuyu",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8864
#   },
#   {
#     "Background": "Lime",
#     "Banana Base": "Camo",
#     "Mouth": "Toothless",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8865
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Wonderland",
#     "Mouth": "Lollipop",
#     "Eyes": "Flirty",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8866
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Stripes",
#     "Mouth": "Trashy",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8867
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Bored",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8868
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Iridescent",
#     "Mouth": "Happy",
#     "Eyes": "Bored",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8869
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Candy Camo",
#     "Mouth": "Cigar",
#     "Eyes": "Flirty",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8870
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Smirk",
#     "Eyes": "Mysterious",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8871
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Red",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Supastar",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8872
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Gold",
#     "Mouth": "Happy",
#     "Eyes": "Googly",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8873
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Peeled",
#     "Mouth": "Toothless",
#     "Eyes": "Stoner",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8874
#   },
#   {
#     "Background": "Pink",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Beatnik",
#     "Eyes": "Eye-patch",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8875
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Ruby",
#     "Mouth": "Sulking",
#     "Eyes": "Mysterious",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8876
#   },
#   {
#     "Background": "Yellow",
#     "Banana Base": "Diamond",
#     "Mouth": "Sulking",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8877
#   },
#   {
#     "Background": "Red",
#     "Banana Base": "Peeled",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8878
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Camo",
#     "Mouth": "Trashy",
#     "Eyes": "Wazowski",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8879
#   },
#   {
#     "Background": "Green",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Trashy",
#     "Eyes": "Donatello",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8880
#   },
#   {
#     "Background": "Slate",
#     "Banana Base": "Peeled Pickle",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Trippy",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8881
#   },
#   {
#     "Background": "Sky",
#     "Banana Base": "Diamond",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Supastar",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8882
#   },
#   {
#     "Background": "Stone",
#     "Banana Base": "Ruby",
#     "Mouth": "Toothless",
#     "Eyes": "Hypno",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8883
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Pride",
#     "Mouth": "Doobie",
#     "Eyes": "Leonardo",
#     "Head Gear": "Small Daisy",
#     "tokenId": 8884
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Blue",
#     "Mouth": "Handlebar 'stache",
#     "Eyes": "Googly",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8885
#   },
#   {
#     "Background": "Indigo",
#     "Banana Base": "Psychedelic",
#     "Mouth": "Cherry Lips",
#     "Eyes": "Bana-love",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8886
#   },
#   {
#     "Background": "Orange",
#     "Banana Base": "Diamond",
#     "Mouth": "Bubblegum",
#     "Eyes": "Perplexed",
#     "Head Gear": "Rice Hat",
#     "tokenId": 8887
#   }
# ]

# %%
# GET TRAIT COUNTS

backgroundcounts = {}
for item in backgrounds:
    backgroundcounts[item] = 0
    
headcounts = {}
for item in heads:
    headcounts[item] = 0
    
facecounts = {}
for item in faces:
    facecounts[item] = 0
    
bodycounts = {}
for item in bodies:
    bodycounts[item] = 0
    
headgearcounts = {}
for item in headgears:
    headgearcounts[item] = 0
    
oneofonecounts = 0

signatures = [137,883,1327,1781,2528,2763,3833,5568,5858,6585,6812,7154,8412]

for banana in traits:
    if banana["tokenId"] in signatures:
        oneofonecounts += 1
    else:    
#     print(banana)
        backgroundcounts[banana["Background"]] += 1
        headcounts[banana["Head"]] += 1
        facecounts[banana["Face"]] += 1
        bodycounts[banana["Body"]] += 1
        headgearcounts[banana["Head Gear"]] += 1
    
print("background:", backgroundcounts)
print("head:", headcounts)
print("face:", facecounts)
print("body:", bodycounts)
print("headgear:", headgearcounts)
print("1/1:",oneofonecounts)
# Out:
# background: {'Red': 186, 'Orange': 214, 'Yellow': 203, 'Lime': 208, 'Green': 190, 'Sky': 204, 'Indigo': 211, 'Purple': 196, 'Pink': 208, 'Slate': 214, 'Stone': 184}
# head: {'Red': 205, 'Orange': 205, 'Yellow': 197, 'Lime': 205, 'Green': 217, 'Sky': 191, 'Indigo': 212, 'Purple': 197, 'Pink': 198, 'Slate': 195, 'Stone': 196}
# face: {'Default': 555, 'Content': 551, 'Happy': 535, 'Grumpy': 577}
# body: {'Sweater': 735, 'Hoodies': 760, 'Suit and Tie': 723}
# headgear: {'Small Daisy': 743, 'Rice Hat': 737, 'Default': 738}
# 1/1: 4

# %%
# WRITE METADATA TO JSON FILE

with open('traits2.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)

# %%
backgroundfiles
# Out:
# {'Red': 'bg1',
#  'Orange': 'bg2',
#  'Yellow': 'bg3',
#  'Lime': 'bg4',
#  'Green': 'bg5',
#  'Sky': 'bg6',
#  'Indigo': 'bg7',
#  'Purple': 'bg8',
#  'Pink': 'bg9',
#  'Slate': 'bg10',
#  'Stone': 'bg11'}

# %%
#### IMAGE GENERATION
    
for item in traits:

    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Heads/{headfiles[item["Head"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Faces/{facefiles[item["Face"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Bodies/{bodyfiles[item["Body"]]}.png').convert('RGBA')
    im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')


    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
    com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com4.convert('RGB')
#     display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./output/" + file_name)
    print(f'{str(item["tokenId"])} done')

# %%
# READ METADATA IF YOU ALREADY HAVE A JSON FILE

with open("traitsfinal.json", 'r') as f:
        traits = json.load(f)

# %%
traits[2050]

# %%
flip_ids = [8057, 8835, 8880, 6612, 5788, 8333, 2173, 8704, 7351, 6671, 4847, 5575, 4864, 2418, 2944, 5845, 552, 1161, 2390, 4383, 8126, 439, 1055, 3435, 7957, 1209, 6438, 6578, 6244, 3490, 4149, 8510, 113, 7193, 5728, 4731, 810, 2949, 3158, 1475, 1242, 4137, 7112, 5852, 7845, 3493, 377, 4272, 5494, 2919, 6818, 2828, 1089, 4914, 5054, 160, 3991, 7625, 6265, 8160, 7331, 4802, 1442, 3850, 171, 3469, 193, 7171, 6328, 5852, 6504, 6639, 2637, 1918, 8607, 4460, 5257, 926, 6114, 8428, 8173, 4565, 5857, 2021, 430, 7708, 4799, 8065, 1609, 4807, 5802, 3371, 8722, 5594, 3034, 2087, 3684, 7878, 7908]

# %%
for m in flip_ids:
    img = Image.open(f'./output/{str(m)}.jpg')
    im_mirror = ImageOps.mirror(img)
    im_mirror.save(f'./flipped/{str(m)}.jpg')

# %%
balds = [4378, 7459, 6945, 4644, 5999, 6337, 6675, 4179, 8467, 5482, 4531, 2016, 3790, 1305, 355]

for bald in balds:
    traits[bald]["Head Gear"] = "None"
    
#### BALDS
    
for bald in balds:
    
    item = traits[bald]
    
    im1 = Image.open(f'./Backgrounds/{backgroundfiles[item["Background"]]}.jpg').convert('RGBA')
    im2 = Image.open(f'./Bananas/{bananafiles[item["Banana Base"]]}.png').convert('RGBA')
    im3 = Image.open(f'./Mouths/{mouthfiles[item["Mouth"]]}.png').convert('RGBA')
    im4 = Image.open(f'./Eyes/{eyefiles[item["Eyes"]]}.png').convert('RGBA')
#     im5 = Image.open(f'./Headgear/{headgearfiles[item["Head Gear"]]}.png').convert('RGBA')


    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
#     com4 = Image.alpha_composite(com3, im5)

    #Convert to RGB
    rgb_im = com3.convert('RGB')
#     display(rgb_im.resize((400,400), Image.NEAREST))

    file_name = str(item["tokenId"]) + ".jpg"
    rgb_im.save("./balds/" + file_name)
    print(f'{str(item["tokenId"])} done')

# %%
madboogielogos = [ 1334, 8120, 3430, 3439, 4175, 7710, 1842, 2428, 3553, 4764, 3439 ]

# %%
for logo in madboogielogos:

    im1 = Image.open(f'./output2/{logo}.jpg').convert('RGBA')
    im2 = Image.open(f'./Logo_static.png').convert('RGBA')
    com1 = Image.alpha_composite(im1, im2).convert('RGB')
    com1.save(f'./boogielogo/{logo}.jpg')

# %%
## ADD IPFS HASH TO JSON, ASSUMING YOU HAVE A JSON FILE LIKE THIS:

'''
{
"QmeBdP4zNCEEbqm9Y2UZb6skg8RVLkgDzQ2ojgZf71cBc8": "0",
"QmWBLUBgVJfSGQDHDR5LNyccRatnsBDjUwtCv7DpiQ9N11": "1",
"QmejsSBzpYyeG8SgyZejrCxrABS4t7e1fjysstBJkNr6Bg": "10",
"QmSVRL6dGQVzUXXy6Q4dPa3mebS755Xeek1b9ZejMyfY8L": "11",
"QmZYBEBbR3SBA56UVSdcGyRKQqceQ2s35paoGrtuixqP6F": "12",
"QmYHZkLv8EAfz3PW8Sfoxb9q64Dp5GZDrsA3soZhteJcLZ": "13",
"QmfHendumMaxewRf6WHCwqGdqbQMSyjv2BvHRVbKNfSfLm": "14",
"QmaAzUXKmpmu85yprJG4RDj8b1DdKxS6r3rbarCHAjtrZX": "15",
"QmS4auQV9y8agQCatWYcBKWPEHbyX2CXS1qAxFoGnGmE7W": "16",
"Qmd98fff2dWLxuUbt2sCMmtcGMGHh93Cfc8Qi3nrieG1FC": "17",
"QmWKTi9tH4HsukveKQ4NnzzV2R9RwPtV158iac9ttnD7Si": "18",
"QmXXD5p2NTS4JtuQiJPJQRdm7fNb69d9siAMzKHr7EPkJj": "19",
"QmQMUzcnFwxCDx9UAPditJ77BRHaPri9eooBxxZKZgQXCN": "2",
"QmQPyYCPuzTLkfGRXnsDV599vi5myc1wByVYAtiS3pa8Da": "20",
"QmNobN7UAchYkGtKB4smCcpvS8KtHjmizqgYNJjzx4dbkx": "3",
"QmQoYWWUfjrgKTmCpTizLh4wiSQb6UcLwRPEwLJfHskj7h": "4",
"Qmf4paFPr1bm73gMf5jnC5Z63gD5dz4Dhn8Vc2tAznx51w": "5",
"QmUFxGMvdnL3EgFMqxfuv8WjuUKLeUtycJ8bnryRuj5yWg": "6",
"QmV5gjEaXDiLP8baFiVZFvg5KjXDEyrGjukgoXaLmz95Jf": "7",
"QmbmiZi87dyi6ujwwtSLkR8D3hkM14PeRCpQg4UcR5aeyJ": "8",
"QmddrDppXDqhsVxtEMKvvzZCFZGZVToHRQGqyzeCsbo49e": "9"
...
}




'''


with open("jsonlocation", 'r') as f:
    hashes = json.load(f)
    
for k,v in hashes.items():
    print(k,v)
    traits[v]["imageIPFS"] = k

# %%
traits

# %%
with open('traitsfinal.json', 'w') as outfile:
    json.dump(traits, outfile, indent=4)
